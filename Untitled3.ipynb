# %% [markdown]
# <a href="https://colab.research.google.com/github/vidyashreem46/qr-code/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install qrcode pillow

# %%
import qrcode

url = "https://vidyashreem46.github.io/profile-website/"

img = qrcode.make(url)
img.save("vidyashree_profile_qr.png")

print("QR code created successfully!")
# Out:
# QR code created successfully!
